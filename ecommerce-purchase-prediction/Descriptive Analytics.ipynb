# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
df= pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Dissertation/dataset.xlsx")
# Out:
# Mounted at /content/drive

# %%
print("Dataset Overview:")
print(df.info())

# missing values
print("\nMissing Values:\n", df.isnull().sum())

print("\nDescriptive Statistics:\n", df.describe())
print("\nSkewness of Numerical Features:\n", df.skew(numeric_only=True))
print("\nKurtosis of Numerical Features:\n", df.kurt(numeric_only=True))
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12330 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  12330 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12330 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  object
#  11  OperatingSystems         12330 non-null  int64
#  12  Browser                  12330 non-null  int64
#  13  Region                   12330 non-null  int64
#  14  TrafficType              12330 non-null  int64
#  15  VisitorType              12330 non-null  object
#  16  Weekend                  12330 non-null  bool
#  17  Revenue                  12330 non-null  bool
# dtypes: bool(2), float64(7), int64(7), object(2)
# memory usage: 1.5+ MB
# None
#
# Missing Values:
#  Administrative             0
# Administrative_Duration    0
# Informational              0
# Informational_Duration     0
# ProductRelated             0
# ProductRelated_Duration    0
# BounceRates                0
# ExitRates                  0
# PageValues                 0
# SpecialDay                 0
# Month                      0
# OperatingSystems           0
# Browser                    0
# Region                     0
# TrafficType                0
# VisitorType                0
# Weekend                    0
# Revenue                    0
# dtype: int64
#
# Descriptive Statistics:
#         Administrative  Administrative_Duration  Informational  \
# count    12330.000000             12330.000000   12330.000000
# mean         2.315166                80.818611       0.503569
# std          3.321784               176.779107       1.270156
# min          0.000000                 0.000000       0.000000
# 25%          0.000000                 0.000000       0.000000
# 50%          1.000000                 7.500000       0.000000
# 75%          4.000000                93.256250       0.000000
# max         27.000000              3398.750000      24.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count            12330.000000    12330.000000             12330.000000
# mean                34.472398       31.731468              1194.746220
# std                140.749294       44.475503              1913.669288
# min                  0.000000        0.000000                 0.000000
# 25%                  0.000000        7.000000               184.137500
# 50%                  0.000000       18.000000               598.936905
# 75%                  0.000000       38.000000              1464.157214
# max               2549.375000      705.000000             63973.522230
#
#         BounceRates     ExitRates    PageValues    SpecialDay  \
# count  12330.000000  12330.000000  12330.000000  12330.000000
# mean       0.022191      0.043073      5.889258      0.061427
# std        0.048488      0.048597     18.568437      0.198917
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.014286      0.000000      0.000000
# 50%        0.003112      0.025156      0.000000      0.000000
# 75%        0.016813      0.050000      0.000000      0.000000
# max        0.200000      0.200000    361.763742      1.000000
#
#        OperatingSystems       Browser        Region   TrafficType
# count      12330.000000  12330.000000  12330.000000  12330.000000
# mean           2.124006      2.357097      3.147364      4.069586
# std            0.911325      1.717277      2.401591      4.025169
# min            1.000000      1.000000      1.000000      1.000000
# 25%            2.000000      2.000000      1.000000      2.000000
# 50%            2.000000      2.000000      3.000000      2.000000
# 75%            3.000000      2.000000      4.000000      4.000000
# max            8.000000     13.000000      9.000000     20.000000
#
# Skewness of Numerical Features:
#  Administrative             1.960357
# Administrative_Duration    5.615719
# Informational              4.036464
# Informational_Duration     7.579185
# ProductRelated             4.341516
# ProductRelated_Duration    7.263228
# BounceRates                2.947855
# ExitRates                  2.148789
# PageValues                 6.382964
# SpecialDay                 3.302667
# OperatingSystems           2.066285
# Browser                    3.242350
# Region                     0.983549
# TrafficType                1.962987
# Weekend                    1.265962
# Revenue                    1.909509
# dtype: float64
#
# Kurtosis of Numerical Features:
#  Administrative               4.701146
# Administrative_Duration     50.556739
# Informational               26.932266
# Informational_Duration      76.316853
# ProductRelated              31.211707
# ProductRelated_Duration    137.174164
# BounceRates                  7.723159
# ExitRates                    4.017035
# PageValues                  65.635694
# SpecialDay                   9.913659
# OperatingSystems            10.456843
# Browser                     12.746733
# Region                      -0.148680
# TrafficType                  3.479711
# Weekend                     -0.397404
# Revenue                      1.646493
# dtype: float64

# %%
# **2. Class Distribution (Purchases vs No Purchases)**
revenue_counts = df["Revenue"].value_counts()
custom_colors = ["#0096c7", "#ff4500"]
plt.figure(figsize=(5,4))
sns.barplot(x=revenue_counts.index, y=revenue_counts.values, palette=custom_colors,edgecolor='black', width= 0.4)
plt.xticks(ticks=[0,1], labels=["No Purchase", "Purchase"])

plt.xlabel("Purchase Status",fontname="Calibri", fontsize=10)
plt.ylabel("Total Revenue", fontsize=10)
plt.title("Distribution of Purchases (Revenue)", fontsize=10)
sns.set_style("white")
plt.grid(False)
plt.show()
import seaborn as sns

plt.savefig("pic.png", dpi=300, bbox_inches="tight")
# Out:
# <ipython-input-3-3126d1dbc4bb>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=revenue_counts.index, y=revenue_counts.values, palette=custom_colors,edgecolor='black', width= 0.4)
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.

# %%
plt.figure(figsize=(4,4))

custom_colors = ["#0096c7", "#ff4500"]
labels = ["No Purchase", "Purchase"]
# Create a pie chart
plt.pie(df["Revenue"].value_counts(), labels=labels, autopct='%1.1f%%',
        startangle=140, colors=custom_colors , wedgeprops={'edgecolor': 'black'})

plt.title("Distribution of Purchases (Revenue)", fontsize=10)
plt.show()

# %%
# ** Analyzing Page Visit Types**
page_types = ["Administrative", "Informational", "ProductRelated"]
page_visits = df[page_types].sum()

plt.figure(figsize=(5,4))
sns.barplot(x=page_visits.index, y=page_visits.values, palette="viridis",edgecolor='black', width= 0.4)
plt.xlabel("Page Type",fontsize=10)
plt.ylabel("Total Visits",fontsize=10)
plt.title("Total Visits by Page Type",fontsize=10)
plt.show()

# ** Page Visits vs. Purchase Correlation**
page_revenue_correlation = df.groupby("Revenue")[page_types].mean()
print("\nPage Visit vs Revenue Correlation:\n", page_revenue_correlation)
# ** Correlation Matrix (Heatmap)**
plt.figure(figsize=(8,7))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="Wistia", fmt=".2f")
plt.title("Feature Correlation Heatmap",fontsize=10)
plt.show()

# ** Histograms of Numerical Features**
df.hist(figsize=(14,10), bins=30, edgecolor="black")
plt.suptitle("Distribution of Numerical Features", fontsize=10)
plt.show()

# ** Visitor Type Distribution**
plt.figure(figsize=(5,4))
sns.countplot(data=df, x="VisitorType", palette="viridis",edgecolor='black',width=0.4)
plt.xlabel("Visitor Type",fontsize=10)
plt.ylabel("Count",fontsize=10)
plt.title("Distribution of Visitor Types",fontsize=10)
plt.show()

# ** Traffic Source Distribution**
plt.figure()
sns.countplot(data=df, x="TrafficType", palette="viridis",edgecolor='black')
plt.xlabel("Traffic Source",fontsize=10)
plt.ylabel("Count",fontsize=10)
plt.title("Traffic Type Distribution",fontsize=10)
plt.xticks(rotation=0)
plt.show()
# Out:
# <ipython-input-5-31da03ee5797>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=page_visits.index, y=page_visits.values, palette="viridis",edgecolor='black', width= 0.4)
# Page Visit vs Revenue Correlation:
#           Administrative  Informational  ProductRelated
# Revenue
# False          2.117732       0.451833       28.714642
# True           3.393606       0.786164       48.210168
# <ipython-input-5-31da03ee5797>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="VisitorType", palette="viridis",edgecolor='black',width=0.4)
# <ipython-input-5-31da03ee5797>:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="TrafficType", palette="viridis",edgecolor='black')

# %%
# Convert boolean values
df["Weekend"] = df["Weekend"].astype(int)
df["Revenue"] = df["Revenue"].astype(int)

plt.style.use("ggplot")
# 1. Revenue Percentage by Visitor Type
visitor_revenue = df.groupby("VisitorType")["Revenue"].mean() * 100

plt.figure(figsize=(5,4))
custom_colors = ["#0096c7", "#ff4500","#ffb300"]
sns.barplot(x=visitor_revenue.index, y=visitor_revenue.values, palette=custom_colors,edgecolor='black',width=0.4)
plt.xlabel("Type of Visitor", fontsize=10)
plt.ylabel("Revenue Conversion Rate (%)", fontsize=10)
plt.title("Revenue Percentage by Different Visitor Types", fontsize=10)
sns.set_style("white")
plt.grid(False)
plt.ylim(0, max(visitor_revenue.values) + 5)
plt.xticks(rotation=0)
plt.show()

# 2. Page Visited Type Distribution
page_types = ["Administrative", "Informational", "ProductRelated"]
page_visits = df[page_types].sum()

plt.figure(figsize=(5,4))
sns.barplot(x=page_visits.index, y=page_visits.values, palette="viridis",edgecolor='black', width=0.4)
plt.xlabel("Types of Pages Visited", fontsize=10)
plt.ylabel("Total Number of Visits", fontsize=10)
plt.title("Distribution of Page Visits", fontsize=10)
plt.xticks(rotation=0)
plt.show()

# 3. Revenue Percentage by Weekend
weekend_revenue = df.groupby("Weekend")["Revenue"].mean() * 100
weekend_labels = ["Weekday", "Weekend"]

plt.figure(figsize=(5,4))
sns.barplot(x=weekend_labels, y=weekend_revenue.values, palette=custom_colors,edgecolor='black',width=0.3)
plt.xlabel("Day Type", fontsize=10)
plt.ylabel("Revenue Percentage (%)", fontsize=10)
plt.title("Revenue Percentage by Weekday vs Weekend", fontsize=10)
plt.ylim(0, max(weekend_revenue.values) + 5)
plt.show()
# Out:
# <ipython-input-6-e71f53d02a2f>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=visitor_revenue.index, y=visitor_revenue.values, palette=custom_colors,edgecolor='black',width=0.4)
# <ipython-input-6-e71f53d02a2f>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=page_visits.index, y=page_visits.values, palette="viridis",edgecolor='black', width=0.4)
# <ipython-input-6-e71f53d02a2f>:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=weekend_labels, y=weekend_revenue.values, palette=custom_colors,edgecolor='black',width=0.3)
# <ipython-input-6-e71f53d02a2f>:40: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.barplot(x=weekend_labels, y=weekend_revenue.values, palette=custom_colors,edgecolor='black',width=0.3)

# %%
plt.style.use("ggplot")

# Revenue by Visitor Type
visitor_counts = df.groupby(["VisitorType", "Revenue"]).size().unstack()

order = ["Returning_Visitor", "New_Visitor", "Other"]
visitor_counts = visitor_counts.reindex(order)
visitor_counts.plot(kind="bar", stacked=True, figsize=(5,4), color=custom_colors, edgecolor='black', width=0.5)
plt.xlabel("Type of Visitor", fontsize=10)
plt.ylabel("Total Visitors", fontsize=10)
plt.title("Revenue Breakdown by Visitor Type", fontsize=10)
plt.legend(title="Revenue", labels=["No Purchase", "Purchase"])
plt.xticks(rotation=0)
sns.set_style("white")
plt.grid(False)
plt.show()


# 2. Page Visited Type Distribution
df_melted = df.melt(id_vars=["Revenue"], value_vars=["Administrative", "Informational", "ProductRelated"],
                    var_name="PageType", value_name="VisitCount")

page_counts = df_melted.groupby(["PageType", "Revenue"]).sum().unstack()
colors = plt.cm.viridis([0.2, 0.8])
page_counts.plot(kind="bar", stacked=True, figsize=(5,4),color=colors,edgecolor='black', width=0.4)
plt.xlabel("Types of Pages Visited", fontsize=10)
plt.ylabel("Total Number of Visits", fontsize=10)
plt.title("Page Visits Breakdown (Distinction by Purchase)", fontsize=10)
plt.legend(title="Revenue", labels=["No Purchase", "Purchase"])
plt.xticks(rotation=0)
sns.set_style("white")
plt.grid(False)
plt.show()

# %%
# Convert 'Month' to categorical
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "June", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
df["Month"] = pd.Categorical(df["Month"], categories=month_order, ordered=True)

# Calculate revenue trends per month
monthly_revenue = df.groupby("Month")["Revenue"].mean() * 100  # Convert to percentage

# Plot line graph
plt.figure(figsize=(5,4))
sns.lineplot(x=monthly_revenue.index, y=monthly_revenue.values, marker="o", color="red", linewidth=2.5)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Revenue Percentage (%)", fontsize=12)
plt.title("Revenue Trends Across Months", fontsize=14)
plt.xticks(rotation=45)
plt.grid(True, linestyle="--", alpha=0.6)
sns.set_style("white")
plt.grid(False)
plt.show()
# Out:
# <ipython-input-8-9dde83399f21>:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   monthly_revenue = df.groupby("Month")["Revenue"].mean() * 100  # Convert to percentage

# %%
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "June", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
df["Month"] = pd.Categorical(df["Month"], categories=month_order, ordered=True)

# Calculate monthly totals
monthly_revenue = df.groupby("Month")["Revenue"].sum()
monthly_visits = df.groupby("Month")["Revenue"].count()
monthly_exit_rate = df.groupby("Month")["ExitRates"].mean() * 100

#  Purchases vs. Non-Purchases per Month
monthly_data = df.groupby(["Month", "Revenue"]).size().unstack().fillna(0)

plt.figure(figsize=(5,4))
monthly_data.plot(kind="bar", stacked=True, figsize=(5,4),color=("#0096c5", "#ff4500"),width=1)
plt.xlabel("Month", fontsize=10)
plt.ylabel("Total Sessions", fontsize=10)
plt.title("Monthly Purchases vs. Non-Purchases", fontsize=11)
plt.xticks(rotation=0, fontsize=9)
plt.legend(title="Revenue", labels=["No Purchase", "Purchase"])
plt.grid(axis="y", linestyle="--", alpha=0.6)
sns.set_style("white")
plt.grid(False)
plt.show()



#  Heatmap: Exit Rates, Revenue, and Visits Per Month
heatmap_data = pd.DataFrame({
    "Total Visitors": monthly_visits,
    "Total Purchases": monthly_revenue,
    "Avg Exit Rate (%)": monthly_exit_rate
})

plt.figure(figsize=(7,5))
sns.heatmap(heatmap_data, annot=True, cmap="Wistia", fmt=".1f", linewidths=0.5)
plt.title("Heatmap of Monthly Trends", fontsize=11)
plt.xlabel("Metrics", fontsize=10)
plt.ylabel("Month", fontsize=8)
plt.xticks(rotation=0, fontsize=10)
plt.show()
# Out:
# <ipython-input-27-fed4cf4c3160>:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   monthly_revenue = df.groupby("Month")["Revenue"].sum()  # Absolute count of purchases
# <ipython-input-27-fed4cf4c3160>:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   monthly_visits = df.groupby("Month")["Revenue"].count()  # Total visitors (sessions)
# <ipython-input-27-fed4cf4c3160>:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   monthly_exit_rate = df.groupby("Month")["ExitRates"].mean() * 100  # Avg exit rate per month
# <ipython-input-27-fed4cf4c3160>:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   monthly_data = df.groupby(["Month", "Revenue"]).size().unstack().fillna(0)

# %%
# Convert 'Month' to categorical type with ordered months
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "June", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
df["Month"] = pd.Categorical(df["Month"], categories=month_order, ordered=True)
# Calculate absolute revenue counts per month
monthly_revenue = df.groupby("Month")["Revenue"].sum()

# Plot line graph with absolute values
plt.figure(figsize=(6,4))
sns.lineplot(x=monthly_revenue.index, y=monthly_revenue.values, marker="o", color="purple", linewidth=2.5)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Total Purchases (Revenue)", fontsize=12)
plt.title("Total Revenue Trend Across Months", fontsize=14)
plt.xticks(rotation=45)
plt.grid(True, linestyle="--", alpha=0.6)
sns.set_style("white")
plt.grid(False)
plt.show()
# Out:
# <ipython-input-10-6cdeccd4d04d>:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   monthly_revenue = df.groupby("Month")["Revenue"].sum()  # Absolute count of purchases

# %%
plt.style.use("ggplot")
# Scatter plot for Administrative Pages vs Exit Rate
plt.figure(figsize=(6,3))
sns.scatterplot(x=df["Administrative"], y=df["ExitRates"], alpha=0.5, color="#471164FF")
plt.xlabel("Administrative Pages Visited")
plt.ylabel("Exit Rate")
plt.title("Exit Rate vs. Administrative Pages Visited")
plt.grid(True, linestyle="--", alpha=0.6)
sns.set_style("white")
plt.grid(False)
plt.show()

# Scatter plot for Informational Pages vs Exit Rate
plt.figure(figsize=(6,3))
sns.scatterplot(x=df["Informational"], y=df["ExitRates"], alpha=0.5, color="#31688EFF")
plt.xlabel("Informational Pages Visited")
plt.ylabel("Exit Rate")
plt.title("Exit Rate vs. Informational Pages Visited")
plt.grid(True, linestyle="--", alpha=0.6)
sns.set_style("white")
plt.grid(False)
plt.show()

# Scatter plot for Product-Related Pages vs Exit Rate
plt.figure(figsize=(6,3))
sns.scatterplot(x=df["ProductRelated"], y=df["ExitRates"], alpha=0.5, color="#27AD81FF")
plt.xlabel("Product-Related Pages Visited")
plt.ylabel("Exit Rate")
plt.title("Exit Rate vs. Product-Related Pages Visited")
plt.grid(True, linestyle="--", alpha=0.6)
sns.set_style("white")
plt.grid(False)
plt.show()



# Boxplot for Page Values across Page Types
df_melted = df.melt(id_vars=["PageValues"], value_vars=["Administrative", "Informational", "ProductRelated"],
                    var_name="PageType", value_name="VisitCount")

plt.figure(figsize=(6,3))
sns.boxplot(x="PageType", y="PageValues", data=df_melted, palette="Blues")
plt.xlabel("Page Type")
plt.ylabel("Page Value")
plt.title("Page Values Across Different Page Types")
plt.grid(True, linestyle="--", alpha=0.6)
sns.set_style("white")
plt.grid(False)
plt.show()

# Weekend vs Revenue
weekend_counts = df.groupby(["Weekend", "Revenue"]).size().unstack()

plt.figure(figsize=(5,4))
weekend_counts.plot(kind="bar", stacked=True, figsize=(6,5), width=0.3)
plt.xlabel("Day Type", fontsize=12)
plt.ylabel("Total Visitors", fontsize=12)
plt.title("Revenue Breakdown by Weekend vs Weekday", fontsize=14)
plt.xticks(ticks=[0,1], labels=["Weekday", "Weekend"], rotation=0)
plt.legend(title="Revenue", labels=["No Purchase", "Purchase"])
plt.grid(axis='y', linestyle="--", alpha=0.6)
plt.show()

# Pie chart for Weekend vs Revenue
plt.figure(figsize=(5,4))
weekend_labels = ["Weekday Purchases", "Weekend Purchases"]
weekend_revenue = df[df["Revenue"] == 1]["Weekend"].value_counts()


plt.pie(weekend_revenue, labels=weekend_labels, autopct='%1.1f%%',
        startangle=140, colors=("#0096c7", "#ff4500"), wedgeprops={'edgecolor': 'black'})
plt.title("Proportion of Purchases on Weekdays vs. Weekends", fontsize=14)
plt.show()
# Out:
# <ipython-input-11-594aebfbe056>:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="PageType", y="PageValues", data=df_melted, palette="Blues")

# %%
visitor_counts = df["VisitorType"].value_counts()
colors = ["#0096c7", "#ff4500", "#ffb300"]

# Create the pie chart
plt.figure(figsize=(5,4))
plt.pie(visitor_counts, labels=visitor_counts.index, autopct='%1.1f%%',
        startangle=140, colors=colors, wedgeprops={'edgecolor': 'black'})

plt.title("Distribution of Visitor Types", fontsize=10)
plt.show()

# %%
# Define model performance data
data = {
    "Model": ["Logistic Regression", "Decision Tree", "Random Forest", "XGBoost", "SVM"],
    "Accuracy": [0.905253, 0.899256, 0.929000, 0.925402, 0.916047],
    "Precision": [0.929771, 0.909046, 0.920904, 0.925180, 0.921693],
    "Recall": [0.876679, 0.887236, 0.938580, 0.925624, 0.909309],
    "F1-Score": [0.902445, 0.898009, 0.929658, 0.925402, 0.915459],
    "ROC-AUC": [0.966250, 0.899172, 0.981598, 0.980327, 0.970805]
}

# Convert the data into a DataFrame
results_df = pd.DataFrame(data)

plt.style.use("ggplot")

# Simple Bar Plot
plt.figure(figsize=(10,6))
sns.barplot(x="Model", y="Accuracy", data=results_df, palette="viridis", edgecolor="black")
plt.xlabel("Machine Learning Model", fontsize=12)
plt.ylabel("Accuracy Score", fontsize=12)
plt.title("Comparison of Model Accuracies", fontsize=14)
plt.xticks(rotation=45)
plt.ylim(0.85, 1)
plt.show()

# Grouped Bar Chart
metrics = ["Accuracy", "Precision", "Recall", "F1-Score", "ROC-AUC"]
melted_df = results_df.melt(id_vars="Model", value_vars=metrics, var_name="Metric", value_name="Score")

plt.figure(figsize=(12,6))
sns.barplot(x="Model", y="Score", hue="Metric", data=melted_df, palette="coolwarm", edgecolor="black")
plt.xlabel("Machine Learning Model", fontsize=12)
plt.ylabel("Score", fontsize=12)
plt.title("Comparison of Model Performance Metrics", fontsize=14)
plt.xticks(rotation=45)
plt.ylim(0.85, 1)
plt.legend(title="Metric")
plt.show()
# Out:
# <ipython-input-13-e310a1a2571b>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Model", y="Accuracy", data=results_df, palette="viridis", edgecolor="black")
